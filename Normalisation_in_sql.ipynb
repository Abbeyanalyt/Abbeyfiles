# %% [markdown]
# ![Slide1.JPG](attachment:b729fc3d-2927-4f82-a195-b987dacfbe98.JPG)

# %% [markdown]
# ![Slide2.JPG](attachment:e8ccbf21-5c89-40f1-8d6e-b6c9f75c8b80.JPG)

# %% [markdown]
# ![Slide3.JPG](attachment:5429969d-078e-4c7c-ae4b-7389a2a7611c.JPG)

# %% [markdown]
# ![Slide4.JPG](attachment:8811102a-9654-4c9e-bc44-1c5d5e126bf6.JPG)

# %% [markdown]
# ![Slide5.JPG](attachment:09b68362-a9d9-4118-af5f-ba75fee851eb.JPG)

# %% [markdown]
# ![Slide6.JPG](attachment:b07e20cd-d45f-4ac2-95cc-b15e3416b9b8.JPG)

# %% [markdown]
# ![Slide7.JPG](attachment:31ec423f-a84e-4139-aab9-506735948cf8.JPG)

# %% [markdown]
# ![Slide8.JPG](attachment:09b56434-b8c0-4c97-9a48-3c1b9341c009.JPG)
